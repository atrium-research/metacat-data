# %% [markdown]
# # Retrieval of vocabularies and mappings for CLARIN

# %%
# Preamble

import re
import requests
import shutil

# Define some common constants
CCR_API_BASE = 'https://vocabularies.clarin.eu/clavas/rest/v1/'
CCR_VOCAB = 'ccr'
VLO_API_BASE = 'https://vlo.clarin-dev.eu/api'
COMPONENT_REGISTRY_BASE = 'https://catalog.clarin.eu/ds/ComponentRegistry/rest'

# Create output directories for data

import os
DATA_DIR = 'data'
CCR_DATA_DIR = DATA_DIR + '/ccr'
PROFILES_DATA_DIR = DATA_DIR + '/profiles'
VLO_FACETS_DATA_DIR = DATA_DIR + '/facets'
VLO_MAPPING_DATA_DIR = DATA_DIR + '/mappings'
for dataDir in [DATA_DIR, CCR_DATA_DIR, PROFILES_DATA_DIR, VLO_FACETS_DATA_DIR, VLO_MAPPING_DATA_DIR]:
    if not os.path.exists(dataDir):
        print("Creating data directory: ", dataDir)
        os.mkdir(dataDir)

# %% [markdown]
# ## Vocabularies

# %%
############################################################
### Concepts from CLARIN Concept Registry (CCR)
############################################################

from skosmos_client import SkosmosClient
from urllib.parse import urlencode, quote_plus

skosmos = SkosmosClient(CCR_API_BASE)
ccrVocab = skosmos.get_vocabulary(CCR_VOCAB)

# schemes = [{'label':'test', 'uri':'http://hdl.handle.net/11459/CCR_P-LexicalResources_ce3edd5c-07a7-b345-dcfa-789a9b4bc980'}]
ccrConceptSchemes = ccrVocab['conceptschemes']

# %%
for scheme in ccrConceptSchemes:
    outfileName = CCR_DATA_DIR + '/' + re.sub('.*/','', scheme['uri']) + '.xml'
    if os.path.exists(outfileName):
        print('- Skipping download of concept scheme', scheme['label'], 'to', outfileName, '(file already exists)')
    else:
        print('- Downloading concept scheme', scheme['label'], 'to', outfileName)
        # retrieve concept scheme
        payload = {'uri': scheme['uri'], 'format': 'application/rdf+xml'}
        url = CCR_API_BASE + CCR_VOCAB + '/data'
        
        # retrieve and save to data directory
        response = requests.get(url, params=payload)
        with open(outfileName, 'w') as f:
            f.write(response.text)

    ### If we wanted, we could also read the concept scheme into a graph
    # graph = rdflib.Graph()
    # sourceUrl=url + '?' + urlencode(payload)
    # graph = graph.parse(source=sourceUrl, format='xml')
    # for subject in graph.subjects():
    #     print(subject)
# Out:
# - Skipping download of concept scheme Dialogue Acts to data/ccr/CCR_P-DialogueActs_955814a6-6c07-c143-94eb-b2551c2d51cb.xml (file already exists)
# - Skipping download of concept scheme Language Codes to data/ccr/CCR_P-LanguageCodes_a122c1a3-1912-fecd-07a2-8685522dfeca.xml (file already exists)
# - Skipping download of concept scheme Language Resource Ontology to data/ccr/CCR_P-LanguageResourceOntology_05399e1d-4f23-8fc1-5088-eb5afbf0cd91.xml (file already exists)
# - Skipping download of concept scheme Lexical Resources to data/ccr/CCR_P-LexicalResources_ce3edd5c-07a7-b345-dcfa-789a9b4bc980.xml (file already exists)
# - Skipping download of concept scheme Lexical Semantics to data/ccr/CCR_P-LexicalSemantics_2906bf39-6db8-90ed-da57-c7a3cc03c9c9.xml (file already exists)
# - Skipping download of concept scheme Lexicography to data/ccr/CCR_P-Lexicography_630911fa-0687-1e55-c846-37ebe24f3182.xml (file already exists)
# - Skipping download of concept scheme Metadata to data/ccr/CCR_P-Metadata_6f3f84d1-6f06-6291-4e20-4cd361cca128.xml (file already exists)
# - Skipping download of concept scheme Morphosyntax to data/ccr/CCR_P-Morphosyntax_f701a84e-9171-1e2d-22cf-6528c2571d42.xml (file already exists)
# - Skipping download of concept scheme Multilingual Information Management to data/ccr/CCR_P-MultilingualInformationManagement_ae12d298-6867-1428-839c-5a624aeaad94.xml (file already exists)
# - Skipping download of concept scheme Semantic Content Representation to data/ccr/CCR_P-SemanticContentRepresentation_1448f330-771b-ad11-987f-7293629f0801.xml (file already exists)
# - Skipping download of concept scheme Sign Language to data/ccr/CCR_P-SignLanguage_8f51ce1b-211d-9682-a8e7-aeb0f2a79e03.xml (file already exists)
# - Skipping download of concept scheme Syntax to data/ccr/CCR_P-Syntax_e7dbb854-a006-9939-4863-1236a4062a1b.xml (file already exists)
# - Skipping download of concept scheme Terminology to data/ccr/CCR_P-Terminology_5b77056e-4634-1b16-a143-3697c33c17a7.xml (file already exists)
# - Skipping download of concept scheme Translation to data/ccr/CCR_P-Translation_e7ebeaa2-68f1-34c8-6301-249173bf6ccf.xml (file already exists)
# - Skipping download of concept scheme not available to data/ccr/CCR_P-notavailable_dc55639d-6b2b-a05a-ced0-9d394432ae43.xml (file already exists)
# - Skipping download of concept scheme undecided to data/ccr/CCR_P-undecided_0103ef85-e040-85f0-c3a1-7b26f5659821.xml (file already exists)

# %%
############################################################
### Controlled vocabularies from profile specifications
############################################################

## Retrieve profile IDs (or load precompiled list)
vloProfileIdsFacetUrl = VLO_API_BASE + '/facets/_componentProfileId'
# make request and retrieve as json
response = requests.get(vloProfileIdsFacetUrl).json()
# collect ids from facet value/count response
profileIds = list(map(lambda v: v['value'], response['values']))
print("Found", len(profileIds), "profile identifiers")
# Out:
# Found 145 profile identifiers

# %%
## Retrieve profile specifications
for profileId in profileIds:
    outfileName = PROFILES_DATA_DIR + '/' + profileId + '.xml'
    if os.path.exists(outfileName):
        print('- Skipping download of profile specification', profileId, 'to', outfileName, '(file already exists)')
    else:
        print('- Downloading profile specification', profileId, 'to', outfileName)
        # retrieve and save to data directory
        url = COMPONENT_REGISTRY_BASE + '/registry/profiles/' + profileId + '/xml'
        response = requests.get(url)
        if response.status_code == 200:
            with open(outfileName, 'w') as f:
                f.write(response.text)
        else:
            print('Warning: profile specification not found for', profileId)
# Out:
# - Skipping download of profile specification clarin.eu:cr1:p_1288172614026 to data/profiles/clarin.eu:cr1:p_1288172614026.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700954 to data/profiles/clarin.eu:cr1:p_1328259700954.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1610707853541 to data/profiles/clarin.eu:cr1:p_1610707853541.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1475136016208 to data/profiles/clarin.eu:cr1:p_1475136016208.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1407745712035 to data/profiles/clarin.eu:cr1:p_1407745712035.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1349361150622 to data/profiles/clarin.eu:cr1:p_1349361150622.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1288172614023 to data/profiles/clarin.eu:cr1:p_1288172614023.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1407745712064 to data/profiles/clarin.eu:cr1:p_1407745712064.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700947 to data/profiles/clarin.eu:cr1:p_1328259700947.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1456409483189 to data/profiles/clarin.eu:cr1:p_1456409483189.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1369140737145 to data/profiles/clarin.eu:cr1:p_1369140737145.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1633000337997 to data/profiles/clarin.eu:cr1:p_1633000337997.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1498745062850 to data/profiles/clarin.eu:cr1:p_1498745062850.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700945 to data/profiles/clarin.eu:cr1:p_1328259700945.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1562754657370 to data/profiles/clarin.eu:cr1:p_1562754657370.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700946 to data/profiles/clarin.eu:cr1:p_1328259700946.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700951 to data/profiles/clarin.eu:cr1:p_1328259700951.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1336550377513 to data/profiles/clarin.eu:cr1:p_1336550377513.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1403526079380 to data/profiles/clarin.eu:cr1:p_1403526079380.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1417617523856 to data/profiles/clarin.eu:cr1:p_1417617523856.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1562754657284 to data/profiles/clarin.eu:cr1:p_1562754657284.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700928 to data/profiles/clarin.eu:cr1:p_1328259700928.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1644311493069 to data/profiles/clarin.eu:cr1:p_1644311493069.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1610707853702 to data/profiles/clarin.eu:cr1:p_1610707853702.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1366895758247 to data/profiles/clarin.eu:cr1:p_1366895758247.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1366895758244 to data/profiles/clarin.eu:cr1:p_1366895758244.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1712653174418 to data/profiles/clarin.eu:cr1:p_1712653174418.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1396012485083 to data/profiles/clarin.eu:cr1:p_1396012485083.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1361876010571 to data/profiles/clarin.eu:cr1:p_1361876010571.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1366895758243 to data/profiles/clarin.eu:cr1:p_1366895758243.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1440426460262 to data/profiles/clarin.eu:cr1:p_1440426460262.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1381926654438 to data/profiles/clarin.eu:cr1:p_1381926654438.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1595321762428 to data/profiles/clarin.eu:cr1:p_1595321762428.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1331113992512 to data/profiles/clarin.eu:cr1:p_1331113992512.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1639731773869 to data/profiles/clarin.eu:cr1:p_1639731773869.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1361876010680 to data/profiles/clarin.eu:cr1:p_1361876010680.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1430905751615 to data/profiles/clarin.eu:cr1:p_1430905751615.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1357720977468 to data/profiles/clarin.eu:cr1:p_1357720977468.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1380106710826 to data/profiles/clarin.eu:cr1:p_1380106710826.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1307535113335 to data/profiles/clarin.eu:cr1:p_1307535113335.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1407745711925 to data/profiles/clarin.eu:cr1:p_1407745711925.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1345561703620 to data/profiles/clarin.eu:cr1:p_1345561703620.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1375880372947 to data/profiles/clarin.eu:cr1:p_1375880372947.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1360931019836 to data/profiles/clarin.eu:cr1:p_1360931019836.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1387365569663 to data/profiles/clarin.eu:cr1:p_1387365569663.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1493735943947 to data/profiles/clarin.eu:cr1:p_1493735943947.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1388512733002 to data/profiles/clarin.eu:cr1:p_1388512733002.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1355150532312 to data/profiles/clarin.eu:cr1:p_1355150532312.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1721373444016 to data/profiles/clarin.eu:cr1:p_1721373444016.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1357720977461 to data/profiles/clarin.eu:cr1:p_1357720977461.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1527668176122 to data/profiles/clarin.eu:cr1:p_1527668176122.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1527668176126 to data/profiles/clarin.eu:cr1:p_1527668176126.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1375880372976 to data/profiles/clarin.eu:cr1:p_1375880372976.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1320657629644 to data/profiles/clarin.eu:cr1:p_1320657629644.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1475136016242 to data/profiles/clarin.eu:cr1:p_1475136016242.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1633000337958 to data/profiles/clarin.eu:cr1:p_1633000337958.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1685529187070 to data/profiles/clarin.eu:cr1:p_1685529187070.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1527668176116 to data/profiles/clarin.eu:cr1:p_1527668176116.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1527668176047 to data/profiles/clarin.eu:cr1:p_1527668176047.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1342181139640 to data/profiles/clarin.eu:cr1:p_1342181139640.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1644311493066 to data/profiles/clarin.eu:cr1:p_1644311493066.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1387365569699 to data/profiles/clarin.eu:cr1:p_1387365569699.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1696338267562 to data/profiles/clarin.eu:cr1:p_1696338267562.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1610707853684 to data/profiles/clarin.eu:cr1:p_1610707853684.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1527668176123 to data/profiles/clarin.eu:cr1:p_1527668176123.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1653377925732 to data/profiles/clarin.eu:cr1:p_1653377925732.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1685529187068 to data/profiles/clarin.eu:cr1:p_1685529187068.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1455633534543 to data/profiles/clarin.eu:cr1:p_1455633534543.xml (file already exists)
# - Downloading profile specification clarin.eu:cr1:p_1475136016193 to data/profiles/clarin.eu:cr1:p_1475136016193.xml
# Warning: profile specification not found for clarin.eu:cr1:p_1475136016193
# - Skipping download of profile specification clarin.eu:cr1:p_1475136016239 to data/profiles/clarin.eu:cr1:p_1475136016239.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1428388179419 to data/profiles/clarin.eu:cr1:p_1428388179419.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700944 to data/profiles/clarin.eu:cr1:p_1328259700944.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1299509410083 to data/profiles/clarin.eu:cr1:p_1299509410083.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1361876010587 to data/profiles/clarin.eu:cr1:p_1361876010587.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1290431694581 to data/profiles/clarin.eu:cr1:p_1290431694581.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1548239945780 to data/profiles/clarin.eu:cr1:p_1548239945780.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1271859438164 to data/profiles/clarin.eu:cr1:p_1271859438164.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1685529187069 to data/profiles/clarin.eu:cr1:p_1685529187069.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1708423613606 to data/profiles/clarin.eu:cr1:p_1708423613606.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1357720977494 to data/profiles/clarin.eu:cr1:p_1357720977494.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1459844210457 to data/profiles/clarin.eu:cr1:p_1459844210457.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1361876010554 to data/profiles/clarin.eu:cr1:p_1361876010554.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1387365569700 to data/profiles/clarin.eu:cr1:p_1387365569700.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1524652309875 to data/profiles/clarin.eu:cr1:p_1524652309875.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1527668176124 to data/profiles/clarin.eu:cr1:p_1527668176124.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1381926654456 to data/profiles/clarin.eu:cr1:p_1381926654456.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1595321762460 to data/profiles/clarin.eu:cr1:p_1595321762460.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1290431694580 to data/profiles/clarin.eu:cr1:p_1290431694580.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1361876010653 to data/profiles/clarin.eu:cr1:p_1361876010653.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1562754657363 to data/profiles/clarin.eu:cr1:p_1562754657363.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1721373444015 to data/profiles/clarin.eu:cr1:p_1721373444015.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1272022528363 to data/profiles/clarin.eu:cr1:p_1272022528363.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1369752611624 to data/profiles/clarin.eu:cr1:p_1369752611624.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1456409483202 to data/profiles/clarin.eu:cr1:p_1456409483202.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1721373443931 to data/profiles/clarin.eu:cr1:p_1721373443931.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1290431694579 to data/profiles/clarin.eu:cr1:p_1290431694579.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1521028545544 to data/profiles/clarin.eu:cr1:p_1521028545544.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1353678848745 to data/profiles/clarin.eu:cr1:p_1353678848745.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1422885449331 to data/profiles/clarin.eu:cr1:p_1422885449331.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1733830015114 to data/profiles/clarin.eu:cr1:p_1733830015114.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1324638957739 to data/profiles/clarin.eu:cr1:p_1324638957739.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1357720977528 to data/profiles/clarin.eu:cr1:p_1357720977528.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1361876010608 to data/profiles/clarin.eu:cr1:p_1361876010608.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1548239945774 to data/profiles/clarin.eu:cr1:p_1548239945774.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1380106710825 to data/profiles/clarin.eu:cr1:p_1380106710825.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1427452477080 to data/profiles/clarin.eu:cr1:p_1427452477080.xml (file already exists)
# - Downloading profile specification clarin.eu:cr1:p_1487686159207 to data/profiles/clarin.eu:cr1:p_1487686159207.xml
# Warning: profile specification not found for clarin.eu:cr1:p_1487686159207
# - Skipping download of profile specification clarin.eu:cr1:p_1659015263839 to data/profiles/clarin.eu:cr1:p_1659015263839.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1271859438162 to data/profiles/clarin.eu:cr1:p_1271859438162.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1380106710823 to data/profiles/clarin.eu:cr1:p_1380106710823.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1386164908461 to data/profiles/clarin.eu:cr1:p_1386164908461.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1447674760338 to data/profiles/clarin.eu:cr1:p_1447674760338.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1469541567394 to data/profiles/clarin.eu:cr1:p_1469541567394.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1527668176128 to data/profiles/clarin.eu:cr1:p_1527668176128.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1633000337972 to data/profiles/clarin.eu:cr1:p_1633000337972.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1288172614014 to data/profiles/clarin.eu:cr1:p_1288172614014.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1302702320451 to data/profiles/clarin.eu:cr1:p_1302702320451.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1311927752306 to data/profiles/clarin.eu:cr1:p_1311927752306.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1320144203804 to data/profiles/clarin.eu:cr1:p_1320144203804.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700934 to data/profiles/clarin.eu:cr1:p_1328259700934.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700935 to data/profiles/clarin.eu:cr1:p_1328259700935.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1328259700936 to data/profiles/clarin.eu:cr1:p_1328259700936.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1345561703730 to data/profiles/clarin.eu:cr1:p_1345561703730.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1345561703731 to data/profiles/clarin.eu:cr1:p_1345561703731.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1349361150727 to data/profiles/clarin.eu:cr1:p_1349361150727.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1357720977520 to data/profiles/clarin.eu:cr1:p_1357720977520.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1357720977526 to data/profiles/clarin.eu:cr1:p_1357720977526.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1368554033446 to data/profiles/clarin.eu:cr1:p_1368554033446.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1369140737141 to data/profiles/clarin.eu:cr1:p_1369140737141.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1369140737143 to data/profiles/clarin.eu:cr1:p_1369140737143.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1369140737144 to data/profiles/clarin.eu:cr1:p_1369140737144.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1369752611626 to data/profiles/clarin.eu:cr1:p_1369752611626.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1371047304769 to data/profiles/clarin.eu:cr1:p_1371047304769.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1392642184799 to data/profiles/clarin.eu:cr1:p_1392642184799.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1404130561238 to data/profiles/clarin.eu:cr1:p_1404130561238.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1422885449343 to data/profiles/clarin.eu:cr1:p_1422885449343.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1423750293168 to data/profiles/clarin.eu:cr1:p_1423750293168.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1430905751614 to data/profiles/clarin.eu:cr1:p_1430905751614.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1430905751641 to data/profiles/clarin.eu:cr1:p_1430905751641.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1442920133046 to data/profiles/clarin.eu:cr1:p_1442920133046.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1487686159249 to data/profiles/clarin.eu:cr1:p_1487686159249.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1524652309872 to data/profiles/clarin.eu:cr1:p_1524652309872.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1524652309874 to data/profiles/clarin.eu:cr1:p_1524652309874.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1562754657343 to data/profiles/clarin.eu:cr1:p_1562754657343.xml (file already exists)
# - Skipping download of profile specification clarin.eu:cr1:p_1595321762461 to data/profiles/clarin.eu:cr1:p_1595321762461.xml (file already exists)

# %%
## Collect XPaths of vocabs

from lxml import etree
# profileIds = ['clarin.eu:cr1:p_1380106710826']

# Loop over profiles
allVocabs = {}
for profileId in profileIds:
    #Parse XML
    infileName = PROFILES_DATA_DIR + '/' + profileId + '.xml'
    try:
        xmlTree = etree.parse(infileName)
    except OSError:
        print("Skipping", profileId, " - specification file could not be read")
        break
    except LmxError as err:
        print("Skipping", profileId, " - file could not be processed:", err)
        break
        
    root = xmlTree.getroot()
    
    # Find vocabularies
    
    # Element vocabs
    elementEnums = root.findall('.//CMD_Element/ValueScheme/enumeration')
    attributeEnums = root.findall('.//AttributeList/Attribute/ValueScheme/enumeration')
    
    vocabs = []
    
    # Process enums
    for enumElement in elementEnums + attributeEnums:
        containers = enumElement.xpath('../..')
        if len(containers) > 0:
            container = containers[0]
            conceptLink = None
            # Look for concept link
            if container.tag == 'CMD_Element':
                conceptLink = container.get('ConceptLink')
            elif container.tag == 'Attribute':
                conceptLinkEl = container.xpath('./ConceptLink')
                if len(conceptLinkEl) > 0:
                    conceptLink = conceptLinkEl[0].text
            vocabs.append({'concept': conceptLink, 'path': xmlTree.getpath(enumElement)})
    
    print('- Found',len(vocabs),'vocabularies in',profileId)

    if len(vocabs) > 0:
        # Add info for proile to collection
        allVocabs[profileId] = vocabs
# Out:
# - Found 60 vocabularies in clarin.eu:cr1:p_1288172614026
# - Found 4 vocabularies in clarin.eu:cr1:p_1328259700954
# - Found 12 vocabularies in clarin.eu:cr1:p_1610707853541
# - Found 2 vocabularies in clarin.eu:cr1:p_1475136016208
# - Found 27 vocabularies in clarin.eu:cr1:p_1407745712035
# - Found 105 vocabularies in clarin.eu:cr1:p_1349361150622
# - Found 0 vocabularies in clarin.eu:cr1:p_1288172614023
# - Found 11 vocabularies in clarin.eu:cr1:p_1407745712064
# - Found 4 vocabularies in clarin.eu:cr1:p_1328259700947
# - Found 0 vocabularies in clarin.eu:cr1:p_1456409483189
# - Found 7 vocabularies in clarin.eu:cr1:p_1369140737145
# - Found 11 vocabularies in clarin.eu:cr1:p_1633000337997
# - Found 0 vocabularies in clarin.eu:cr1:p_1498745062850
# - Found 4 vocabularies in clarin.eu:cr1:p_1328259700945
# - Found 41 vocabularies in clarin.eu:cr1:p_1562754657370
# - Found 4 vocabularies in clarin.eu:cr1:p_1328259700946
# - Found 4 vocabularies in clarin.eu:cr1:p_1328259700951
# - Found 76 vocabularies in clarin.eu:cr1:p_1336550377513
# - Found 0 vocabularies in clarin.eu:cr1:p_1403526079380
# - Found 27 vocabularies in clarin.eu:cr1:p_1417617523856
# - Found 0 vocabularies in clarin.eu:cr1:p_1562754657284
# - Found 38 vocabularies in clarin.eu:cr1:p_1328259700928
# - Found 27 vocabularies in clarin.eu:cr1:p_1644311493069
# - Found 279 vocabularies in clarin.eu:cr1:p_1610707853702
# - Found 60 vocabularies in clarin.eu:cr1:p_1366895758247
# - Found 60 vocabularies in clarin.eu:cr1:p_1366895758244
# - Found 0 vocabularies in clarin.eu:cr1:p_1712653174418
# - Found 26 vocabularies in clarin.eu:cr1:p_1396012485083
# - Found 396 vocabularies in clarin.eu:cr1:p_1361876010571
# - Found 12 vocabularies in clarin.eu:cr1:p_1366895758243
# - Found 5 vocabularies in clarin.eu:cr1:p_1440426460262
# - Found 41 vocabularies in clarin.eu:cr1:p_1381926654438
# - Found 12 vocabularies in clarin.eu:cr1:p_1595321762428
# - Found 28 vocabularies in clarin.eu:cr1:p_1331113992512
# - Found 11 vocabularies in clarin.eu:cr1:p_1639731773869
# - Found 11 vocabularies in clarin.eu:cr1:p_1361876010680
# - Found 0 vocabularies in clarin.eu:cr1:p_1430905751615
# - Found 4 vocabularies in clarin.eu:cr1:p_1357720977468
# - Found 12 vocabularies in clarin.eu:cr1:p_1380106710826
# - Found 7 vocabularies in clarin.eu:cr1:p_1307535113335
# - Found 133 vocabularies in clarin.eu:cr1:p_1407745711925
# - Found 3 vocabularies in clarin.eu:cr1:p_1345561703620
# - Found 15 vocabularies in clarin.eu:cr1:p_1375880372947
# - Found 80 vocabularies in clarin.eu:cr1:p_1360931019836
# - Found 6 vocabularies in clarin.eu:cr1:p_1387365569663
# - Found 29 vocabularies in clarin.eu:cr1:p_1493735943947
# - Found 19 vocabularies in clarin.eu:cr1:p_1388512733002
# - Found 172 vocabularies in clarin.eu:cr1:p_1355150532312
# - Found 7 vocabularies in clarin.eu:cr1:p_1721373444016
# - Found 4 vocabularies in clarin.eu:cr1:p_1357720977461
# - Found 56 vocabularies in clarin.eu:cr1:p_1527668176122
# - Found 107 vocabularies in clarin.eu:cr1:p_1527668176126
# - Found 12 vocabularies in clarin.eu:cr1:p_1375880372976
# - Found 25 vocabularies in clarin.eu:cr1:p_1320657629644
# - Found 5 vocabularies in clarin.eu:cr1:p_1475136016242
# - Found 127 vocabularies in clarin.eu:cr1:p_1633000337958
# - Found 27 vocabularies in clarin.eu:cr1:p_1685529187070
# - Found 19 vocabularies in clarin.eu:cr1:p_1527668176116
# - Found 18 vocabularies in clarin.eu:cr1:p_1527668176047
# - Found 75 vocabularies in clarin.eu:cr1:p_1342181139640
# - Found 11 vocabularies in clarin.eu:cr1:p_1644311493066
# - Found 25 vocabularies in clarin.eu:cr1:p_1387365569699
# - Found 0 vocabularies in clarin.eu:cr1:p_1696338267562
# - Found 114 vocabularies in clarin.eu:cr1:p_1610707853684
# - Found 58 vocabularies in clarin.eu:cr1:p_1527668176123
# - Found 26 vocabularies in clarin.eu:cr1:p_1653377925732
# - Found 5 vocabularies in clarin.eu:cr1:p_1685529187068
# - Found 0 vocabularies in clarin.eu:cr1:p_1455633534543
# Skipping clarin.eu:cr1:p_1475136016193  - specification file could not be read

# %%
# Example: getting vocabulary values for a single concept
concept = 'http://hdl.handle.net/11459/CCR_C-2571_2be2e583-e5af-34c2-3673-93359ec1f7df'

conceptItems = set()
for profileId in list(allVocabs):
    xmlTree = None
    for info in allVocabs[profileId]:
        if info['concept'] == concept:
            # print(profileId, 'at', info['path'])
            if xmlTree == None:
                # parse specification
                infileName = PROFILES_DATA_DIR + '/' + profileId + '.xml'
                xmlTree = etree.parse(infileName)
            enumeration = xmlTree.xpath(info['path'])
            if len(enumeration) > 0:
                items = enumeration[0].xpath('./item')
                for item in items:
                    conceptItems.add(item.text)

{'concept': concept, 'items': conceptItems}
# TODO(?): we could materialize all vocabularies per concept
# Out:
# {'concept': 'http://hdl.handle.net/11459/CCR_C-2571_2be2e583-e5af-34c2-3673-93359ec1f7df',
#  'items': {'application/epub+zip',
#   'application/json',
#   'application/msword',
#   'application/pdf',
#   'application/ssff',
#   'application/vnd.adobe.flash-movie',
#   'application/vnd.ms-excel',
#   'application/vnd.ms-powerpoint',
#   'application/vnd.oasis.opendocument.graphics',
#   'application/vnd.oasis.opendocument.presentation',
#   'application/vnd.oasis.opendocument.spreadsheet',
#   'application/vnd.oasis.opendocument.text',
#   'application/x-binary',
#   'application/x-tar',
#   'application/x-tex',
#   'application/x-texinfo',
#   'application/x-zip-compressed',
#   'application/xhtml+xml',
#   'application/zip',
#   'audio/aiff',
#   'audio/basic',
#   'audio/midi',
#   'audio/mod',
#   'audio/mp4',
#   'audio/mpeg',
#   'audio/mpeg3',
#   'audio/ogg',
#   'audio/raw',
#   'audio/vnd.wave',
#   'audio/voc',
#   'audio/vorbis',
#   'audio/wav',
#   'audio/webm',
#   'audio/x-adpcm',
#   'audio/x-aiff',
#   'audio/x-au',
#   'audio/x-esps',
#   'audio/x-gsm',
#   'audio/x-mpeg',
#   'audio/x-mpeg-3',
#   'audio/x-nist',
#   'audio/x-realaudio',
#   'audio/x-ssff',
#   'audio/x-voc',
#   'audio/x-wav',
#   'image/bmp',
#   'image/eps',
#   'image/gif',
#   'image/jpeg',
#   'image/pjpeg',
#   'image/png',
#   'image/svg+xml',
#   'image/tiff',
#   'image/vasa',
#   'image/vnd.djvu',
#   'image/x-quicktime',
#   'multipart/x-gzip',
#   'multipart/x-zip',
#   'text/css',
#   'text/csv',
#   'text/folia+xml',
#   'text/html',
#   'text/plain',
#   'text/plain-bas',
#   'text/praat-textgrid',
#   'text/richtext',
#   'text/sgml',
#   'text/xml',
#   'video/avi',
#   'video/mp4',
#   'video/mpeg',
#   'video/msvideo',
#   'video/ogg',
#   'video/quicktime',
#   'video/webm',
#   'video/x-flv',
#   'video/x-motion-jpeg',
#   'video/x-ms-wmv'}}

# %%
############################################################
### VLO facets
############################################################

## Retrieve facets from VLO API
vloFacetsUrl = VLO_API_BASE + '/facets'
# make request and retrieve as json
response = requests.get(vloFacetsUrl).json()
# collect ids from facet value/count response
facets = list(map(lambda v: v['name'], response))
print("Found", len(facets), "facets")

# Collect facet values and store in a single list
facetsInfo=[]
for facet in facets:
    facetUrl = VLO_API_BASE + '/facets/' + facet
    response = requests.get(facetUrl).json()
    values = list(map(lambda v: v['value'], response['values']))
    print('Facet info from', facetUrl, ': found', len(values), 'values')
    facetsInfo.append({'facet': facet, 'values': values})
# Out:
# Found 10 facets
# Facet info from https://vlo.clarin-dev.eu/api/facets/languageCode : found 9111 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/collection : found 944 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/resourceClass : found 669 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/modality : found 192 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/format : found 210 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/keywords : found 8607 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/genre : found 1476 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/subject : found 100000 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/country : found 336 values
# Facet info from https://vlo.clarin-dev.eu/api/facets/organisation : found 1779 values

# %%
# Write VLO facet info to a file
import json

facetsOutFile = VLO_FACETS_DATA_DIR + '/vlo-facets.json'
facetsJson = json.dumps(facetsInfo, indent=4)
with open(facetsOutFile, "w") as outfile:
    outfile.write(facetsJson)

print('VLO facet values written to', facetsOutFile)
# Out:
# VLO facet values written to data/facets/vlo-facets.json

# %% [markdown]
# ## Mappings

# %%
############################################################
### Concept - facet mapping
############################################################

facetConceptsMappingUrl = 'https://raw.githubusercontent.com/clarin-eric/VLO-mapping/refs/heads/master/mapping/facetConcepts.xml'
facetConceptsMappingOutFile = VLO_MAPPING_DATA_DIR + '/facetConcepts.xml'

## Retrieve from GitHub and store a copy
response = requests.get(facetConceptsMappingUrl)
with open(facetConceptsMappingOutFile, "w") as outfile:
    outfile.write(response.text)

print('VLO concept - facet mapping written to', facetConceptsMappingOutFile)
# Out:
# VLO concept - facet mapping written to data/mappings/facetConcepts.xml

# %%
############################################################
### Value maps
############################################################

from zipfile import ZipFile
from tempfile import TemporaryDirectory
from io import BytesIO
from zipfile import ZipFile

## Retrieve from GitHub
vloMappingRepoUrl = 'https://github.com/clarin-eric/VLO-mapping/archive/refs/heads/master.zip'
sourceDir = 'VLO-mapping-master/value-maps/dist'
targetDir = VLO_MAPPING_DATA_DIR + '/value-maps'

if os.path.exists(targetDir):
    print('deleting existing target dir', targetDir)
    shutil.rmtree(targetDir)

response = requests.get(vloMappingRepoUrl)
vloMappingRepoZip = response.content
with TemporaryDirectory() as tmpDir:
    with ZipFile(BytesIO(vloMappingRepoZip)) as zip_ref:
        files = [f for f in  zip_ref.namelist() if f.startswith(sourceDir)]
        zip_ref.extractall(members=files, path=tmpDir)
        shutil.move(tmpDir + '/' + sourceDir, targetDir)

print('Value map definitions extracted to', targetDir)
# Out:
# deleting existing target dir data/mappings/value-maps
# Value map definitions extracted to data/mappings/value-maps

# %%
############################################################
### Post-processing maps
############################################################

## Retrieve from GitHub (same repository as value maps)
sourceDir = 'VLO-mapping-master/uniform-maps'
targetDir = VLO_MAPPING_DATA_DIR + '/uniform-maps'

if os.path.exists(targetDir):
    print('deleting existing target dir', targetDir)
    shutil.rmtree(targetDir)

# response = requests.get(vloMappingRepoUrl)
# vloMappingRepoZip = response.content
with TemporaryDirectory() as tmpDir:
    with ZipFile(BytesIO(vloMappingRepoZip)) as zip_ref:
        files = [f for f in  zip_ref.namelist() if f.startswith(sourceDir)]
        zip_ref.extractall(members=files, path=tmpDir)
        shutil.move(tmpDir + '/' + sourceDir, targetDir)

print('Post-processing map definitions extracted to', targetDir)
# Out:
# deleting existing target dir data/mappings/uniform-maps
# Post-processing map definitions extracted to data/mappings/uniform-maps
